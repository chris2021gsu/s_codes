# %% [markdown]
# <a href="https://colab.research.google.com/github/chrizzz1993/sample-code-/blob/main/EDA_haberman_assgt_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

haberman = pd.read_csv("iris.csv")
