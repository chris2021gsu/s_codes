# %%
print('hello')
# Out:
# hello

# %%
a=19
print(a,"is a type of ",type(a))
# Out:
# 19 is a type of  <class 'int'>

# %%
a=2+7j
print(a)
print(isinstance(a,complex))
# Out:
# (2+7j)
# True

# %% [markdown]
# prime number problem

# %%
n1= input("enter from value ")

n2=input("enter to value")
# find all prime numbers between these two numbers 

for num in  range(int(n1),int(n2)+1):
    if num>1:
        isdivisible= False;
        for num2 in range (2,num):
            if num%num2==0:
                isdivisible= True;
        if not isdivisible:
            print(num)
# Out:
# enter from value 5
# enter to value15
# 5
# 7
# 11
# 13
